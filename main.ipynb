# %%
import pandas as pd
import numpy as np

from xgboost import XGBClassifier 

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score
from sklearn.metrics import roc_auc_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
import shap

from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
bankruptcy = pd.read_csv("data.csv")
bankruptcy.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %% [markdown]
# ## Podział ramki danych

# %%
val_bankruptcy = pd.read_csv("data.csv")
X = bankruptcy.drop(["Bankrupt?"], axis=1)
y = bankruptcy["Bankrupt?"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.3, random_state=42
)

# %% [markdown]
# Preprossesing został wykonany jednakowy jak w zadaniu domowym 3

# %%
idx = np.where(bankruptcy.corr()["Bankrupt?"] <0)[0]
bankruptcy.iloc[:,idx] = -bankruptcy.iloc[:,idx]
pd.set_option('display.max_columns', None)
bankruptcy.corr()

bankruptcy = bankruptcy.drop(" Net Income Flag", axis = 1)

columns = X_train.drop(' Liability-Assets Flag', axis = 1).columns

for col in columns:
    lower = X_train[col].quantile(0.025)
    upper = X_train[col].quantile(0.975)
    
    
    X_train[col] = [lower if x < lower else x for x in X_train[col] ]
    X_train[col] = [upper if x > upper else x for x in X_train[col] ]
    X_test[col] = [lower if x < lower else x for x in X_test[col] ]
    X_test[col] = [upper if x > upper else x for x in X_test[col] ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11168/906523481.py in <module>
#       6 bankruptcy = bankruptcy.drop(" Net Income Flag", axis = 1)
#       7
# ----> 8 columns = X_train.drop(' Liability-Assets Flag', axis = 1).columns
#       9
#      10 for col in columns:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
X_train.describe()
# Out:
#         ROA(C) before interest and depreciation before interest  \
# count                                        4773.000000
# mean                                            0.504830
# std                                             0.051937
# min                                             0.380924
# 25%                                             0.476088
# 50%                                             0.502462
# 75%                                             0.534637
# max                                             0.626729
#
#         ROA(A) before interest and % after tax  \
# count                              4773.000000
# mean                                  0.558379
# std                                   0.053890
# min                                   0.412669
# 25%                                   0.535052
# 50%                                   0.559474
# 75%                                   0.588149
# max                                   0.676597
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        4773.000000
# mean                                            0.553485
# std                                             0.051715
# min                                             0.421554
# 25%                                             0.527116
# 50%                                             0.552010
# 75%                                             0.582901
# max                                             0.670132
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              4773.000000                   4773.000000
# mean                  0.608063                      0.608031
# std                   0.010854                      0.010811
# min                   0.589724                      0.589703
# 25%                   0.600463                      0.600455
# 50%                   0.605940                      0.605904
# 75%                   0.613651                      0.613593
# max                   0.639941                      0.639589
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             4773.000000                 4773.000000
# mean                 0.999014                    0.797439
# std                  0.000158                    0.000264
# min                  0.998451                    0.796473
# 25%                  0.998969                    0.797385
# 50%                  0.999022                    0.797462
# 75%                  0.999093                    0.797575
# max                  0.999318                    0.797912
#
#         After-tax net Interest Rate  \
# count                   4773.000000
# mean                       0.809350
# std                        0.000238
# min                        0.808441
# 25%                        0.809310
# 50%                        0.809375
# 75%                        0.809467
# max                        0.809764
#
#         Non-industry income and expenditure/revenue  \
# count                                   4773.000000
# mean                                       0.303523
# std                                        0.000204
# min                                        0.302887
# 25%                                        0.303467
# 50%                                        0.303525
# 75%                                        0.303584
# max                                        0.304110
#
#         Continuous interest rate (after tax)   Operating Expense Rate  \
# count                            4773.000000             4.773000e+03
# mean                                0.781608             1.959282e+09
# std                                 0.000248             3.207746e+09
# min                                 0.780659             1.052292e-04
# 25%                                 0.781566             1.559936e-04
# 50%                                 0.781634             2.722083e-04
# 75%                                 0.781729             4.060000e+09
# max                                 0.782035             9.477000e+09
#
#         Research and development expense rate   Cash flow rate  \
# count                            4.773000e+03      4773.000000
# mean                             1.941191e+09         0.467097
# std                              2.563581e+09         0.009601
# min                              0.000000e+00         0.448745
# 25%                              1.295462e-04         0.461560
# 50%                              4.920000e+08         0.465081
# 75%                              3.410000e+09         0.470921
# max                              8.674000e+09         0.496792
#
#         Interest-bearing debt interest rate   Tax rate (A)  \
# count                          4.773000e+03    4773.000000
# mean                           2.753824e+06       0.108944
# std                            1.648865e+07       0.119292
# min                            0.000000e+00       0.000000
# 25%                            2.020202e-04       0.000000
# 50%                            3.210321e-04       0.071363
# 75%                            5.330533e-04       0.203057
# max                            1.040000e+08       0.427057
#
#         Net Value Per Share (B)   Net Value Per Share (A)  \
# count               4773.000000               4773.000000
# mean                   0.188938                  0.188940
# std                    0.025110                  0.025146
# min                    0.148114                  0.147920
# 25%                    0.173528                  0.173528
# 50%                    0.184105                  0.184105
# 75%                    0.199233                  0.199275
# max                    0.267667                  0.267667
#
#         Net Value Per Share (C)   Persistent EPS in the Last Four Seasons  \
# count               4773.000000                               4773.000000
# mean                   0.188973                                  0.227614
# std                    0.025159                                  0.023784
# min                    0.147920                                  0.181365
# 25%                    0.173570                                  0.214617
# 50%                    0.184105                                  0.224260
# 75%                    0.199275                                  0.237875
# max                    0.267667                                  0.298856
#
#         Cash Flow Per Share   Revenue Per Share (Yuan ¥)  \
# count           4773.000000                  4773.000000
# mean               0.323368                     0.036595
# std                0.010541                     0.031639
# min                0.298660                     0.003615
# 25%                0.317783                     0.015578
# 50%                0.322452                     0.027376
# 75%                0.328500                     0.045843
# max                0.352104                     0.152613
#
#         Operating Profit Per Share (Yuan ¥)  \
# count                           4773.000000
# mean                               0.107948
# std                                0.019091
# min                                0.076297
# 25%                                0.096002
# 50%                                0.104145
# 75%                                0.115707
# max                                0.168227
#
#         Per Share Net profit before tax (Yuan ¥)  \
# count                                4773.000000
# mean                                    0.183045
# std                                     0.023031
# min                                     0.139203
# 25%                                     0.170294
# 50%                                     0.179408
# 75%                                     0.192739
# max                                     0.253672
#
#         Realized Sales Gross Profit Growth Rate  \
# count                               4773.000000
# mean                                   0.022140
# std                                    0.000171
# min                                    0.021916
# 25%                                    0.022064
# 50%                                    0.022102
# 75%                                    0.022153
# max                                    0.022908
#
#         Operating Profit Growth Rate   After-tax Net Profit Growth Rate  \
# count                    4773.000000                        4773.000000
# mean                        0.848069                           0.689407
# std                         0.000262                           0.000860
# min                         0.847368                           0.686080
# 25%                         0.847982                           0.689268
# 50%                         0.848043                           0.689436
# 75%                         0.848122                           0.689643
# max                         0.849055                           0.691872
#
#         Regular Net Profit Growth Rate   Continuous Net Profit Growth Rate  \
# count                      4773.000000                         4773.000000
# mean                          0.689407                            0.217596
# std                           0.000861                            0.000094
# min                           0.686080                            0.217237
# 25%                           0.689268                            0.217579
# 50%                           0.689436                            0.217598
# 75%                           0.689643                            0.217621
# max                           0.691872                            0.217877
#
#         Total Asset Growth Rate   Net Value Growth Rate  \
# count              4.773000e+03             4773.000000
# mean               5.504608e+09                0.000485
# std                2.880003e+09                0.000087
# min                1.072699e-04                0.000363
# 25%                4.880000e+09                0.000441
# 50%                6.400000e+09                0.000461
# 75%                7.390000e+09                0.000499
# max                9.470000e+09                0.000819
#
#         Total Asset Return Growth Rate Ratio   Cash Reinvestment %  \
# count                            4773.000000           4773.000000
# mean                                0.264108              0.379820
# std                                 0.000710              0.012582
# min                                 0.262522              0.342219
# 25%                                 0.263750              0.374856
# 50%                                 0.264045              0.380435
# 75%                                 0.264386              0.386545
# max                                 0.266270              0.407365
#
#         Current Ratio   Quick Ratio   Interest Expense Ratio  \
# count     4773.000000   4773.000000              4773.000000
# mean         0.013972      0.010313                 0.630967
# std          0.010303      0.009290                 0.001161
# min          0.003439      0.000983                 0.628003
# 25%          0.007519      0.004673                 0.630612
# 50%          0.010545      0.007386                 0.630701
# 75%          0.016343      0.012220                 0.631126
# max          0.051793      0.045378                 0.634768
#
#         Total debt/Total net worth   Debt ratio %   Net worth/Assets  \
# count                  4773.000000    4773.000000        4773.000000
# mean                      0.007133       0.112842           0.887158
# std                       0.005735       0.050813           0.050813
# min                       0.000795       0.023315           0.780781
# 25%                       0.003021       0.073102           0.850712
# 50%                       0.005558       0.111618           0.888382
# 75%                       0.009316       0.149288           0.926898
# max                       0.026089       0.219219           0.976685
#
#         Long-term fund suitability ratio (A)   Borrowing dependency  \
# count                            4773.000000            4773.000000
# mean                                0.007107               0.374151
# std                                 0.004009               0.004950
# min                                 0.004973               0.369637
# 25%                                 0.005240               0.370168
# 50%                                 0.005643               0.372659
# 75%                                 0.006806               0.376265
# max                                 0.025136               0.390290
#
#         Contingent liabilities/Net worth   Operating profit/Paid-in capital  \
# count                        4773.000000                        4773.000000
# mean                            0.005736                           0.107839
# std                             0.000718                           0.018942
# min                             0.005366                           0.076529
# 25%                             0.005366                           0.095958
# 50%                             0.005366                           0.104027
# 75%                             0.005774                           0.115500
# max                             0.008429                           0.167598
#
#         Net profit before tax/Paid-in capital  \
# count                             4773.000000
# mean                                 0.181599
# std                                  0.021728
# min                                  0.141664
# 25%                                  0.169324
# 50%                                  0.178252
# 75%                                  0.190936
# max                                  0.248602
#
#         Inventory and accounts receivable/Net value   Total Asset Turnover  \
# count                                   4773.000000            4773.000000
# mean                                       0.401994               0.138429
# std                                        0.006551               0.086379
# min                                        0.394432               0.020990
# 25%                                        0.397427               0.076462
# 50%                                        0.400127               0.118441
# 75%                                        0.404490               0.178411
# max                                        0.422750               0.408846
#
#         Accounts Receivable Turnover   Average Collection Days  \
# count                    4773.000000               4773.000000
# mean                        0.001402                  0.006940
# std                         0.001381                  0.003524
# min                         0.000408                  0.000987
# 25%                         0.000710                  0.004383
# 50%                         0.000970                  0.006571
# 75%                         0.001459                  0.008974
# max                         0.007750                  0.016334
#
#         Inventory Turnover Rate (times)   Fixed Assets Turnover Frequency  \
# count                      4.773000e+03                      4.773000e+03
# mean                       2.133326e+09                      1.013520e+09
# count                  4773.000000                 4773.000000
# mean                      0.808347                    0.006498
# std                       0.030539                    0.013568
# min                       0.719723                    0.000255
# 25%                       0.796561                    0.000907
# 50%                       0.810467                    0.002069
# 75%                       0.826101                    0.005242
# max                       0.868295                    0.074885
#
#         No-credit Interval   Gross Profit to Sales  \
# count          4773.000000             4773.000000
# mean              0.623819                0.608061
# std               0.001092                0.010854
# min               0.619921                0.589722
# 25%               0.623635                0.600459
# 50%               0.623876                0.605936
# 75%               0.624168                0.613651
# max               0.626771                0.639943
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          4773.000000           4773.000000
# mean                              0.840833              0.279903
# std                               0.002509              0.004070
# min                               0.832466              0.275338
# 25%                               0.840095              0.276953
# 50%                               0.841148              0.278794
# 75%                               0.842336              0.281491
# max                               0.845057              0.292987
#
#         Degree of Financial Leverage (DFL)  \
# count                          4773.000000
# mean                              0.026968
# std                               0.000626
# min                               0.026109
# 25%                               0.026791
# 50%                               0.026809
# 75%                               0.026914
# max                               0.029980
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        4773.000000              4773.0
# mean                                            0.565516                 1.0
# std                                             0.001336                 0.0
# min                                             0.561649                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565254                 1.0
# 75%                                             0.565729                 1.0
# max                                             0.569666                 1.0
#
#         Equity to Liability
# count           4773.000000
# mean               0.044644
# std                0.030987
# min                0.015382
# 25%                0.024383
# 50%                0.033730
# 75%                0.052676
# max                0.155210

# %% [markdown]
# ### Normalizacja
# Zmieniamy zmienne na wartości z przedziału [0,1]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Modele

# %%
def Consuse_Matrix(model):
    plot_confusion_matrix(model, X_test, y_test) 
    plt.gcf().set_size_inches(6, 5)
    plt.show()

# %% [markdown]
# ## Decission Trees

# %%
from sklearn import tree


clf = tree.DecisionTreeClassifier()
optimization_dict = {
                        "min_impurity_decrease": [0, 0.2, 0.3, 0.4],
                        "max_depth": [80, 90, 100, 110],
                        "min_samples_leaf": [2, 5, 8, 10],
                        "max_leaf_nodes": [5, 10, 20]
                    }

# %% [markdown]
# ### Random search

# %%
from sklearn.model_selection import RandomizedSearchCV

clf_random = RandomizedSearchCV(estimator = clf,

param_distributions = optimization_dict,
               n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = -1)
clf_random.fit(X, y)

# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', optimization_dict, '\n')

# print the best parameters
print ('Best Parameters: ', clf_random.best_params_, ' \n')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# optimization dict:  {'min_impurity_decrease': [0, 0.2, 0.3, 0.4], 'max_depth': [80, 90, 100, 110], 'min_samples_leaf': [2, 5, 8, 10], 'max_leaf_nodes': [5, 10, 20]}
#
# Best Parameters:  {'min_samples_leaf': 5, 'min_impurity_decrease': 0.4, 'max_leaf_nodes': 20, 'max_depth': 80}

# %%
Consuse_Matrix(clf_random)

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

clf = tree.DecisionTreeClassifier()
clf_Grid = GridSearchCV(clf, optimization_dict, 
                     scoring='accuracy', verbose=1)
clf_Grid.fit(X, y)

# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', optimization_dict, '\n')

# print the best parameters
print ('Best Parameters: ', clf_Grid.best_params_, ' \n')
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# optimization dict:  {'min_impurity_decrease': [0, 0.2, 0.3, 0.4], 'max_depth': [80, 90, 100, 110], 'min_samples_leaf': [2, 5, 8, 10], 'max_leaf_nodes': [5, 10, 20]}
#
# Best Parameters:  {'max_depth': 80, 'max_leaf_nodes': 5, 'min_impurity_decrease': 0.2, 'min_samples_leaf': 2}

# %%
Consuse_Matrix(clf_Grid)

# %% [markdown]
# ##  Random Forest

# %%
from sklearn.model_selection import GridSearchCV

rf_model = RandomForestClassifier()
optimization_dict = {
                        'bootstrap': [True],
                        'max_depth': [80, 90, 100, 110],
                        'max_features': [2, 3],
                        'min_samples_leaf': [3, 4, 5],
                        'min_samples_split': [8, 10, 12],
                        'n_estimators': [100, 200, 300, 1000]
                    }

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

rl_random = RandomizedSearchCV(estimator = rf_model,
param_distributions = optimization_dict,
               n_iter = 100, cv = 5, verbose=2, random_state=35, n_jobs = -1)

rl_random.fit(X, y)

# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', optimization_dict, '\n')

# print the best parameters
print ('Best Parameters: ', rl_random.best_params_, ' \n')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# optimization dict:  {'bootstrap': [True], 'max_depth': [80, 90, 100, 110], 'max_features': [2, 3], 'min_samples_leaf': [3, 4, 5], 'min_samples_split': [8, 10, 12], 'n_estimators': [100, 200, 300, 1000]}
#
# Best Parameters:  {'n_estimators': 100, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 2, 'max_depth': 90, 'bootstrap': True}

# %%
Consuse_Matrix(rl_random)

# %% [markdown]
# ### Grind Search

# %%
rf = GridSearchCV(rf_model, optimization_dict, 
                     scoring='accuracy', verbose=1)

rf.fit(X_train, y_train)

# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', optimization_dict, '\n')

# print the best parameters
print ('Best Parameters: ', rf.best_params_, ' \n')
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# optimization dict:  {'min_impurity_decrease': [0, 0.2, 0.3, 0.4], 'max_depth': [80, 90, 100, 110], 'min_samples_leaf': [2, 5, 8, 10], 'max_leaf_nodes': [5, 10, 20]}
#
# Best Parameters:  {'max_depth': 100, 'max_leaf_nodes': 20, 'min_impurity_decrease': 0, 'min_samples_leaf': 2}

# %%
Consuse_Matrix(rf)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn import svm

# defining parameter range
optimization_dict = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

svm = svm.SVC()

# %% [markdown]
# ### Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

svm_random = RandomizedSearchCV(estimator = svm,
param_distributions = optimization_dict,
               n_iter = 100, cv = 5, verbose=2, random_state=35, n_jobs = -1)

svm_random.fit(X, y)

# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', optimization_dict, '\n')

# print the best parameters
print ('Best Parameters: ', svm_random.best_params_, ' \n')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# optimization dict:  {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'kernel': ['rbf']}
#
# Best Parameters:  {'kernel': 'rbf', 'gamma': 1, 'C': 0.1}

# %%
Consuse_Matrix(svm_random)

# %% [markdown]
# ### Grind Search

# %%
from sklearn.model_selection import GridSearchCV
 
grid = GridSearchCV(svm, optimization_dict, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.968 total time=   0.8s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.969 total time=   0.8s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.968 total time=   0.8s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   1.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.970 total time=   1.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.957 total time=   0.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.970 total time=   0.1s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.972 total time=   0.1s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   1.1s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   0.9s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.970 total time=   0.9s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.956 total time=   0.1s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.962 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.950 total time=   0.1s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.970 total time=   1.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.968 total time=   1.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.956 total time=   0.1s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.966 total time=   0.1s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.964 total time=   0.1s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.951 total time=   0.1s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.955 total time=   0.2s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.966 total time=   0.2s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.964 total time=   0.2s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.2s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.955 total time=   0.2s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.966 total time=   0.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.966 total time=   0.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# this prints the contents of the parameters in the optimization_dict
print ('optimization dict: ', param_grid, '\n')

# print the best parameters
print ('Best Parameters: ', grid.best_params_, ' \n')
# Out:
# optimization dict:  {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'kernel': ['rbf']}
#
# Best Parameters:  {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
Consuse_Matrix(grid)
